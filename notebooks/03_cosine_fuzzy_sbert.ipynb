# %% [markdown]
# IDENYA ADALAH FILE KELUAR MASUK
# 1. proses dulu si cosine doang outputnya list down mana x_test yg udah ada di y_train (score apa nya tinggi gitu) dan buat file baru dengan label yes/no
# 2. proses ini ngambil data dari proses no 1 khusus yang no aja jadi yg udah bener ga usah diproses lagi...
# 3. terus begitu sampe terakhir model ML jalan

# %%
# !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Using cached rapidfuzz-3.14.5-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Using cached rapidfuzz-3.14.5-cp311-cp311-win_amd64.whl (1.5 MB)
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.5

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score
from rapidfuzz import process, fuzz

# Load data
train_df = pd.read_csv("data/Hospital_Train.csv")
test_df = pd.read_csv("data/Hospital_Test.csv")

# Clean data
train_df_clean = train_df.dropna(subset=["Hospital Name rev 2"])
X_train = train_df_clean["Hospital_Name (clean)"]
y_train = train_df_clean["Hospital Name rev 2"]
X_test = test_df["Hospital_Name (clean)"]
y_test = test_df["Hospital Name rev 2"]

# TF-IDF vectorization
vectorizer = TfidfVectorizer(ngram_range=(1, 2), sublinear_tf=True)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Cosine similarity prediction
cos_sim_matrix = cosine_similarity(X_test_tfidf, X_train_tfidf)
cosine_top_indices = cos_sim_matrix.argmax(axis=1)
cosine_preds = y_train.iloc[cosine_top_indices].values
cosine_top_scores = cos_sim_matrix.max(axis=1)

# Format clean name
def format_clean_name(name):
    return re.sub(r'[^\w\s&]', '', name).upper().strip()

clean_names = X_test.apply(format_clean_name)

# FINAL PREDICTION LOGIC
final_preds = []
fuzzy_preds = []
fuzzy_scores = []
tfidf_zero_flags = []
tfidf_term_details = []

feature_names = vectorizer.get_feature_names_out()

for i in range(len(X_test)):
    cleaned_input = clean_names.iloc[i]
    actual = y_test.iloc[i]
    tfidf_row = X_test_tfidf[i]

    # Token analyzer
    tokens = vectorizer.build_analyzer()(cleaned_input)

    # TF-IDF vector content
    indices = tfidf_row.nonzero()[1]
    values = tfidf_row.data
    tfidf_tokens = {feature_names[idx] for idx in indices}
    tfidf_score_map = {feature_names[idx]: round(val, 4) for idx, val in zip(indices, values)}
    tfidf_term_details.append(tfidf_score_map)

    # Cek apakah ada token hilang
    missing_tokens = set(tokens) - tfidf_tokens
    has_zero = len(missing_tokens) > 0
    tfidf_zero_flags.append(has_zero)

    # Fuzzy matching
    fuzzy_match, fuzzy_score, _ = process.extractOne(
        cleaned_input,
        y_train.tolist(),  # fix: convert to list
        scorer=fuzz.token_sort_ratio
    )
    fuzzy_preds.append(fuzzy_match)
    fuzzy_scores.append(fuzzy_score)

    # FINAL DECISION FLOW
    if cosine_preds[i] == actual:
        final_preds.append(cosine_preds[i])
    elif has_zero:
        # Use fuzzy result as new input to cosine
        new_input_vector = vectorizer.transform([fuzzy_match])
        new_cos_sim = cosine_similarity(new_input_vector, X_train_tfidf)
        new_top_idx = new_cos_sim.argmax()
        new_cosine_pred = y_train.iloc[new_top_idx]

        if new_cosine_pred == actual:
            final_preds.append(new_cosine_pred)
            # print(f"[{i}] 🌀 Fuzzy → Cosine match: {fuzzy_match} → {new_cosine_pred}")
        else:
            final_preds.append(cleaned_input)
    elif fuzzy_match == actual:
        final_preds.append(fuzzy_match)
    else:
        final_preds.append(cleaned_input)

# Buat hasil dataframe
result_df = pd.DataFrame({
    "Hospital_Name_clean": X_test,
    "Actual": y_test,
    "Cosine_Pred": cosine_preds,
    "Fuzzy_Pred": fuzzy_preds,
    "Fuzzy_Score": fuzzy_scores,
    "Clean_Pred": clean_names,
    "Final_Pred": final_preds,
    "Cosine_Score": cosine_top_scores,
    "TF-IDF_Zero_Found": tfidf_zero_flags,
    "TF-IDF_Terms_Score": tfidf_term_details
})

# Bersihkan spasi ganda
for col in ["Final_Pred", "Fuzzy_Pred"]:
    result_df[col] = result_df[col].str.replace(r"\s+", " ", regex=True).str.strip()

# Tampilkan mismatch & evaluasi
mismatch_df = result_df[result_df["Actual"] != result_df["Final_Pred"]]
accuracy = accuracy_score(y_test, result_df["Final_Pred"])

print("\n🎯 Accuracy:", accuracy)
print("🔥 Total mismatch:", len(mismatch_df))
print("🧠 Total TF-IDF OOV:", sum(tfidf_zero_flags))
mismatch_df.head(10)
# Out:
# 🎯 Accuracy: 0.8883495145631068
# 🔥 Total mismatch: 23
# 🧠 Total TF-IDF OOV: 148
#                                    Hospital_Name_clean  \
# 16                     RS KHUSUS ORTHOEDI KARIMA UTAMA
# 34                                   RS THT PROKLAMASI
# 40                            HERMINA HOSPITALS MADIUN
# 66                                            RSIA BUN
# 67   REVIEW DOR 22 -DOKUMEN LAPORAN OP SUDAH DIKIRI...
# 88                              RSSTELISABETH SEMARANG
# 108                   THE ENT,VOICE DAN SNORING CLINIC
# 110  THE SPORE GASTROENTEROLOGY & LIVER INTERNIST C...
# 111  SPORTSLN ORHOPEDIC CLINIC GELEAGLES MEDICAL CA...
# 112                                   KLINIK AP DAN AP
#
#                                                 Actual  \
# 16                    RS KHUSUS ORTHOPEDI KARIMA UTAMA
# 34                      RS KHUSUS THT BEDAH PROKLAMASI
# 40                                   RS HERMINA MADIUN
# 66                                    RS BUNDA JAKARTA
# 67                              RS BETHESDA YOGYAKARTA
# 88                            RS ST ELISABETH SEMARANG
# 108           MOUNT ELIZABETH MEDICAL CENTRE SINGAPORE
# 110  SPORE GASTROENTEROLOGY & LIVER INTERNIST CENTR...
# 111                                GLENEAGLES HOSPITAL
# 112                    LABORATORIUM DAN KLINIK PRAMITA
#
#                                            Cosine_Pred  \
# 16                        RS KHUSUS BEDAH KARIMA UTAMA
# 34                             RS THT BEDAH PROKLAMASI
# 40                               RS SANTA CLARA MADIUN
# 66                                              RS BUN
# 67                                         RS BETHESDA
# 88                            SILOAM HOSPITAL SEMARANG
# 108        THE ENT SPECIALIST CENTRE PARKWAY SINGAPORE
# 110  SINGAPORE GASTROENTEROLOGY & LIVER INTERNIST C...
# 111                                           E-CLINIC
# 112                                 RS PREMIER BINTARO
#
#                                             Fuzzy_Pred  Fuzzy_Score  \
# 16                    RS KHUSUS ORTHOPEDI KARIMA UTAMA    98.412698
# 34                                       RS PROKLAMASI    86.666667
# 40                              HARI NATIONAL HOSPITAL    69.565217
# 66                                              RS BUN    85.714286
# 67                      RSUP PROF DR R D KANDOU MANADO    48.000000
# 88                               RS ELISABETH SEMARANG    83.720930
# 108                                HE ENDOCRINE CLINIC    68.000000
# 110  SINGAPORE GASTROENTEROLOGY & LIVER INTERNIST C...    78.571429
# 111  SOG ANDY TAN CLINIC FOR WOMEN GLENEAGLES MEDIC...    64.761905
# 112                                      KLINIK ANANDA    75.862069
#
#                                             Clean_Pred  \
# 16                     RS KHUSUS ORTHOEDI KARIMA UTAMA
# 34                                   RS THT PROKLAMASI
# 40                            HERMINA HOSPITALS MADIUN
# 66                                            RSIA BUN
# 67   REVIEW DOR 22 DOKUMEN LAPORAN OP SUDAH DIKIRIM...
# 88                              RSSTELISABETH SEMARANG
# 108                    THE ENTVOICE DAN SNORING CLINIC
# 110  THE SPORE GASTROENTEROLOGY & LIVER INTERNIST C...
# 111  SPORTSLN ORHOPEDIC CLINIC GELEAGLES MEDICAL CA...
# 112                                   KLINIK AP DAN AP
#
#                                             Final_Pred  Cosine_Score  \
# 16                     RS KHUSUS ORTHOEDI KARIMA UTAMA      0.771471
# 34                                   RS THT PROKLAMASI      0.614295
# 40                            HERMINA HOSPITALS MADIUN      0.398326
# 66                                            RSIA BUN      0.587421
# 67   REVIEW DOR 22 DOKUMEN LAPORAN OP SUDAH DIKIRIM...      0.388503
# 88                              RSSTELISABETH SEMARANG      0.533078
# 108                    THE ENTVOICE DAN SNORING CLINIC      0.890817
# 110  THE SPORE GASTROENTEROLOGY & LIVER INTERNIST C...      0.868745
# 111  SPORTSLN ORHOPEDIC CLINIC GELEAGLES MEDICAL CA...      0.364512
# 112                                   KLINIK AP DAN AP      0.422959
#
#      TF-IDF_Zero_Found                                 TF-IDF_Terms_Score
# 16                True  {'karima': 0.543, 'karima utama': 0.543, 'khus...
# 34               False  {'proklamasi': 0.4631, 'rs': 0.0869, 'rs tht':...
# 40                True  {'hermina': 0.4645, 'hospitals': 0.4444, 'madi...
# 66                True                    {'bun': 0.8989, 'rsia': 0.4382}
# 67                True  {'22': 0.3309, 'bethesda': 0.2697, 'by': 0.344...
# 88                True                                  {'semarang': 1.0}
# 108               True  {'clinic': 0.1893, 'dan': 0.2692, 'ent': 0.294...
# 110               True  {'care': 0.2188, 'dan': 0.2315, 'gastroenterol...
# 111               True  {'cantre': 0.8493, 'clinic': 0.3645, 'medical'...
# 112               True    {'ap': 0.9199, 'dan': 0.3316, 'klinik': 0.2093}

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# Optional: save to Excel
result_df.to_excel("NLP_Cosine_Fuzzy_Pred.xlsx", index=False)
print("✅ Predictions saved to 'NLP_Cosine_Fuzzy_Pred.xlsx'")
# Out:
# ✅ Predictions saved to 'NLP_Cosine_Fuzzy_Pred.xlsx'

# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.5.1-py3-none-any.whl.metadata (18 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.12.1-py3-none-any.whl.metadata (33 kB)
# Collecting huggingface-hub>=0.23.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.19.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: torch>=1.11.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.20.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from sentence-transformers) (2.4.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from sentence-transformers) (4.15.0)
# Collecting tqdm>=4.0.0 (from sentence-transformers)
#   Downloading tqdm-4.68.2-py3-none-any.whl.metadata (58 kB)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Collecting regex>=2025.10.22 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading regex-2026.5.9-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading typer-0.26.7-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting click>=8.4.0 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2025.12.0)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading hf_xet-1.5.1-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Collecting typer (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Collecting shellingham>=1.3.0 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: colorama in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from click>=8.4.0->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: networkx in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Downloading sentence_transformers-5.5.1-py3-none-any.whl (588 kB)
#    ---------------------------------------- 0.0/588.9 kB ? eta -:--:--
#    ---------------------------------------- 588.9/588.9 kB 5.3 MB/s  0:00:00
# Downloading transformers-5.12.1-py3-none-any.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.2 MB 10.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/11.2 MB 7.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/11.2 MB 7.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.9/11.2 MB 4.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.2 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.2 MB 4.7 MB/s eta 0:00:02
#    ------------------------- -------------- 7.1/11.2 MB 4.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.2 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.2 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.2 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 5.3 MB/s  0:00:02
# Downloading huggingface_hub-1.19.0-py3-none-any.whl (693 kB)
#    ---------------------------------------- 0.0/693.4 kB ? eta -:--:--
#    ---------------------------------------- 693.4/693.4 kB 5.5 MB/s  0:00:00
# Downloading hf_xet-1.5.1-cp37-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.0 MB 5.0 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.0 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 5.2 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 2.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.7 MB/s  0:00:00
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
# Downloading regex-2026.5.9-cp311-cp311-win_amd64.whl (278 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl (355 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading tqdm-4.68.2-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, shellingham, safetensors, regex, mdurl, hf-xet, click, annotated-doc, markdown-it-py, rich, typer, huggingface-hub, tokenizers, transformers, sentence-transformers
#
#    -------- -------------------------------  3/15 [regex]
#    ---------------- -----------------------  6/15 [click]
#    --------------------- ------------------  8/15 [markdown-it-py]
#    ------------------------ ---------------  9/15 [rich]
#    ------------------------ ---------------  9/15 [rich]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ---------------------------------------- 15/15 [sentence-transformers]
#
# Successfully installed annotated-doc-0.0.4 click-8.4.1 hf-xet-1.5.1 huggingface-hub-1.19.0 markdown-it-py-4.2.0 mdurl-0.1.2 regex-2026.5.9 rich-15.0.0 safetensors-0.8.0 sentence-transformers-5.5.1 shellingham-1.5.4 tokenizers-0.22.2 tqdm-4.68.2 transformers-5.12.1 typer-0.25.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics import accuracy_score
import pandas as pd

# Load data hasil sebelumnya
result_df = pd.read_excel("NLP_Cosine_Fuzzy_Pred.xlsx")
result_df["Final_Pred"] = result_df["Final_Pred"].astype(str).str.strip()
result_df["Actual"] = result_df["Actual"].astype(str).str.strip()

# Step 1: Ambil data yg sudah cocok
correct_df = result_df[result_df["Actual"] == result_df["Final_Pred"]].copy()
X_train_sbert = correct_df["Hospital_Name_clean"].tolist()
y_train_sbert = correct_df["Actual"].tolist()

# Step 2: Ambil data mismatch
mismatch_df = result_df[result_df["Actual"] != result_df["Final_Pred"]].copy()
X_test_sbert = mismatch_df["Hospital_Name_clean"].tolist()
y_test_sbert = mismatch_df["Actual"].tolist()

# Step 3: Embedding SBERT
sbert_model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
X_train_emb = sbert_model.encode(X_train_sbert, convert_to_tensor=True)
X_test_emb = sbert_model.encode(X_test_sbert, convert_to_tensor=True)

# Step 4: Cosine similarity pakai SBERT
sbert_preds = []
for test_vec in X_test_emb:
    cos_scores = util.cos_sim(test_vec, X_train_emb)[0]
    top_idx = cos_scores.argmax().item()
    sbert_preds.append(y_train_sbert[top_idx])

# Step 5: Update prediksi dan simpan SBERT_Pred
for i, idx in enumerate(mismatch_df.index):
    result_df.loc[idx, "SBERT_Pred"] = sbert_preds[i]
    result_df.loc[idx, "Final_Pred"] = sbert_preds[i]

# Step 6: Bersihkan spasi
result_df["Final_Pred"] = result_df["Final_Pred"].str.replace(r"\s+", " ", regex=True).str.strip()
result_df["SBERT_Pred"] = result_df["SBERT_Pred"].astype(str).str.replace(r"\s+", " ", regex=True).str.strip()

# Step 7: Evaluasi ulang
mismatch_df_final = result_df[result_df["Actual"] != result_df["Final_Pred"]][
    ["Hospital_Name_clean", "Actual", "Cosine_Pred", "Fuzzy_Pred", "SBERT_Pred", "Final_Pred"]
]
accuracy_final = accuracy_score(result_df["Actual"], result_df["Final_Pred"])

# Output
print("✅ AFTER SBERT:")
print("🎯 Accuracy:", accuracy_final)
print("🔥 Remaining mismatch:", len(mismatch_df_final))
mismatch_df_final.head(10)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# c:\Users\Bara\miniconda3\envs\ml\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Bara\.cache\huggingface\hub\models--sentence-transformers--paraphrase-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.51k [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ AFTER SBERT:
# 🎯 Accuracy: 0.8980582524271845
# 🔥 Remaining mismatch: 21
#                                    Hospital_Name_clean  \
# 16                     RS KHUSUS ORTHOEDI KARIMA UTAMA
# 34                                   RS THT PROKLAMASI
# 40                            HERMINA HOSPITALS MADIUN
# 66                                            RSIA BUN
# 67   REVIEW DOR 22 -DOKUMEN LAPORAN OP SUDAH DIKIRI...
# 110  THE SPORE GASTROENTEROLOGY & LIVER INTERNIST C...
# 111  SPORTSLN ORHOPEDIC CLINIC GELEAGLES MEDICAL CA...
# 112                                   KLINIK AP DAN AP
# 113                 SUNWAY MEDICAL CENTRE KUALA LUMPUR
# 116                                EYE ANDEAR HOSPITAL
#
#                                                 Actual  \
# 16                    RS KHUSUS ORTHOPEDI KARIMA UTAMA
# 34                      RS KHUSUS THT BEDAH PROKLAMASI
# 40                                   RS HERMINA MADIUN
# 66                                    RS BUNDA JAKARTA
# 67                              RS BETHESDA YOGYAKARTA
# 110  SPORE GASTROENTEROLOGY & LIVER INTERNIST CENTR...
# 111                                GLENEAGLES HOSPITAL
# 112                    LABORATORIUM DAN KLINIK PRAMITA
# 113             SUNWAY MEDICAL CENTRE SDN BHD MALAYSIA
# 116                               EYE AND EAR HOSPITAL
#
#                                            Cosine_Pred  \
# 16                        RS KHUSUS BEDAH KARIMA UTAMA
# 34                             RS THT BEDAH PROKLAMASI
# 40                               RS SANTA CLARA MADIUN
# 66                                              RS BUN
# 67                                         RS BETHESDA
# 110  SINGAPORE GASTROENTEROLOGY & LIVER INTERNIST C...
# 111                                           E-CLINIC
# 112                                 RS PREMIER BINTARO
# 113                     I HEAL MEDICAL CENTRE MALAYSIA
# 116                                             RS EYE
#
#                                             Fuzzy_Pred  \
# 16                    RS KHUSUS ORTHOPEDI KARIMA UTAMA
# 34                                       RS PROKLAMASI
# 40                              HARI NATIONAL HOSPITAL
# 66                                              RS BUN
# 67                      RSUP PROF DR R D KANDOU MANADO
# 110  SINGAPORE GASTROENTEROLOGY & LIVER INTERNIST C...
# 111  SOG ANDY TAN CLINIC FOR WOMEN GLENEAGLES MEDIC...
# 112                                      KLINIK ANANDA
# 113               PARKCITY MEDICAL CENTRE KUALA LUMPUR
# 116                               FUDA CANCER HOSPITAL
#
#                                SBERT_Pred  \
# 16        RS KHUSUS ORTHOPEDI RSOP CIAMIS
# 34        RS KHUSUS ORTHOPEDI RSOP CIAMIS
# 40             BRAWIJAYA HOSPITAL SAHARJO
# 66              RSUD DR ISKAK TULUNGAGUNG
# 67                         RS GRHA KEDOYA
# 110  PAEDIATRIC & GASTROENTEROLOGY CLINIC
# 111       CLINIC UNIVERSITY OF NOTTINGHAM
# 112            APOTEK & LAB KLINIK DEWANI
# 113       GLENEGLES HOSPITAL KUALA LUMPUR
# 116       ADVANCED EYE CLINIC AND SURGERY
#
#                                Final_Pred
# 16        RS KHUSUS ORTHOPEDI RSOP CIAMIS
# 34        RS KHUSUS ORTHOPEDI RSOP CIAMIS
# 40             BRAWIJAYA HOSPITAL SAHARJO
# 66              RSUD DR ISKAK TULUNGAGUNG
# 67                         RS GRHA KEDOYA
# 110  PAEDIATRIC & GASTROENTEROLOGY CLINIC
# 111       CLINIC UNIVERSITY OF NOTTINGHAM
# 112            APOTEK & LAB KLINIK DEWANI
# 113       GLENEGLES HOSPITAL KUALA LUMPUR
# 116       ADVANCED EYE CLINIC AND SURGERY

# %%
# Optional: save to Excel
result_df.to_excel("NLP_Cosine_Fuzzy_SBERT_Pred.xlsx", index=False)
print("✅ Predictions saved to 'NLP_Cosine_Fuzzy_SBERT_Pred.xlsx'")
# Out:
# ✅ Predictions saved to 'NLP_Cosine_Fuzzy_SBERT_Pred.xlsx'
